# %%
import numpy as np
from keras.preprocessing import image
from keras.applications import inception_v3
from keras import backend as K
from PIL import Image

# %%
# Load pre-trained image recognition model
model = inception_v3.InceptionV3()

# %%
# Grab a reference to the first and last layer of the neural net
model_input_layer = model.layers[0].input
model_output_layer = model.layers[-1].output

# %%
# Choose an ImageNet object to fake
# The list of classes is available here: https://gist.github.com/ageitgey/4e1342c10a71981d0b491e1b8227328b
# Class #859 is "toaster"
object_type_to_fake = 859

# %%
# Load the image to hack
img = image.load_img("/content/drive/My Drive/panda.jpg", target_size=(299, 299))
original_image = image.img_to_array(img)

# %%
# Scale the image so all pixel intensities are between [-1, 1] as the model expects
original_image /= 255.
original_image -= 0.5
original_image *= 2.

# %%
# Add a 4th dimension for batch size (as Keras expects)
original_image = np.expand_dims(original_image, axis=0)

# %%
# Pre-calculate the maximum change we will allow to the image
# We'll make sure our hacked image never goes past this so it doesn't look funny.
# A larger number produces an image faster but risks more distortion.
max_change_above = original_image + 0.01
max_change_below = original_image - 0.01

# %%
# Create a copy of the input image to hack on
hacked_image = np.copy(original_image)

# %%
# How much to update the hacked image in each iteration
learning_rate = 0.1

# %%
# Define the cost function.
# Our 'cost' will be the likelihood out image is the target class according to the pre-trained model
cost_function = model_output_layer[0, object_type_to_fake]

# %%
# We'll ask Keras to calculate the gradient based on the input image and the currently predicted class
# In this case, referring to "model_input_layer" will give us back image we are hacking.
gradient_function = K.gradients(cost_function, model_input_layer)[0]

# %%
# Create a Keras function that we can call to calculate the current cost and gradient
# K.learning_phase 返回训练模式/测试模式的flag，该flag是一个用以传入Keras模型的标记，以决定当前模型执行于训练模式下还是测试模式下
grab_cost_and_gradients_from_model = K.function([model_input_layer, K.learning_phase()], [cost_function, gradient_function])

cost = 0.0

# %%
# In a loop, keep adjusting the hacked image slightly so that it tricks the model more and more
# until it gets to at least 80% confidence
iteration = 0
while cost < 0.80:
    # Check how close the image is to our target class and grab the gradients we
    # can use to push it one more step in that direction.
    # Note: It's really important to pass in '0' for the Keras learning mode here!
    # Keras layers behave differently in prediction vs. train modes!
    cost, gradients = grab_cost_and_gradients_from_model([hacked_image, 0])

    # Move the hacked image one step further towards fooling the model
    hacked_image += gradients * learning_rate

    # Ensure that the image doesn't ever change too much to either look funny or to become an invalid image
    hacked_image = np.clip(hacked_image, max_change_below, max_change_above)
    hacked_image = np.clip(hacked_image, -1.0, 1.0)
    iteration = iteration + 1
    if iteration%10 == 1:
      print("第 %d 次时: " %(iteration))
      print(" Model's predicted likelihood that the image is a toaster: {:.8}%".format(cost * 100))
print("第 %d 次时,成功" %(iteration))
print(" Model's predicted likelihood that the image is a toaster: {:.8}%".format(cost * 100))
# Out:
# 第 1 次时:
#  Model's predicted likelihood that the image is a toaster: 0.0050458333%
# 第 11 次时:
#  Model's predicted likelihood that the image is a toaster: 0.0050550618%
# 第 21 次时:
#  Model's predicted likelihood that the image is a toaster: 0.005064264%
# 第 31 次时:
#  Model's predicted likelihood that the image is a toaster: 0.0050734914%
# 第 41 次时:
#  Model's predicted likelihood that the image is a toaster: 0.0050827566%
# 第 51 次时:
#  Model's predicted likelihood that the image is a toaster: 0.0050920829%
# 第 61 次时:
#  Model's predicted likelihood that the image is a toaster: 0.0051014304%
# 第 71 次时:
#  Model's predicted likelihood that the image is a toaster: 0.005110852%
# 第 81 次时:
#  Model's predicted likelihood that the image is a toaster: 0.0051203162%
# 第 91 次时:
#  Model's predicted likelihood that the image is a toaster: 0.005129799%
# 第 101 次时:
#  Model's predicted likelihood that the image is a toaster: 0.0051392501%
# 第 111 次时:
#  Model's predicted likelihood that the image is a toaster: 0.0051487721%
# 第 121 次时:
#  Model's predicted likelihood that the image is a toaster: 0.0051583695%
# 第 131 次时:
#  Model's predicted likelihood that the image is a toaster: 0.0
 次时:
#  Model's predicted likelihood that the image is a toaster: 0.078230369%
# 第 8121 次时:
#  Model's predicted likelihood that the image is a toaster: 0.078833068%
# 第 8131 次时:
#  Model's predicted likelihood that the image is a toaster: 0.079451787%
# 第 8141 次时:
#  Model's predicted likelihood that the image is a toaster: 0.080074894%
# 第 8151 次时:
#  Model's predicted likelihood that the image is a toaster: 0.08070214%
# 第 8161 次时:
#  Model's predicted likelihood that the image is a toaster: 0.081342563%
# 第 8171 次时:
#  Model's predicted likelihood that the image is a toaster: 0.082007167%
# 第 8181 次时:
#  Model's predicted likelihood that the image is a toaster: 0.082689314%
# 第 8191 次时:
#  Model's predicted likelihood that the image is a toaster: 0.083385472%
# 第 8201 次时:
#  Model's predicted likelihood that the image is a toaster: 0.08408773%
# 第 8211 次时:
#  Model's predicted likelihood that the image is a toaster: 0.084799126%
# 第 8221 次时:
#  Model's predicted likelihood that the image is a toaster: 0.085523177%
# 第 8231 次时:
#  Model's predicted likelihood that the image is a toaster: 0.086271908%
# 第 8241 次时:
#  Model's predicted likelihood that the image is a toaster: 0.087052456%
# 第 8251 次时:
#  Model's predicted likelihood that the image is a toaster: 0.087846228%
# 第 8261 次时:
#  Model's predicted likelihood that the image is a toaster: 0.088642613%
# 第 8271 次时:
#  Model's predicted likelihood that the image is a toaster: 0.089453603%
# 第 8281 次时:
#  Model's predicted likelihood that the image is a toaster: 0.090279151%
# 第 8291 次时:
#  Model's predicted likelihood that the image is a toaster: 0.091125659%
# 第 8301 次时:
#  Model's predicted likelihood that the image is a toaster: 0.091964653%
# 第 8311 次时:
#  Model's predicted likelihood that the image is a toaster: 0.092832127%
# 第 8321 次时:
#  Model's predicted likelihood that the image is a toaster: 0.093707396%
# 第 8331 次时:
#  Model's predicted likelihood that the image is a toaster: 0.094598334%
# 第 8341 次时:
#  Model's predicted likelihood that the image is a toaster: 0.095497567%
# 第 8351 次时:
#  Model's predicted likelihood that the image is a toaster: 0.096416281%
# 第 8361 次时:
#  Model's predicted likelihood that the image is a toaster: 0.097361475%
# 第 8371 次时:
#  Model's predicted likelihood that the image is a toaster: 0.098357175%
# 第 8381 次时:
#  Model's predicted likelihood that the image is a toaster: 0.099385635%
# 第 8391 次时:
#  Model's predicted likelihood that the image is a toaster: 0.1004384%
# 第 8401 次时:
#  Model's predicted likelihood that the image is a toaster: 0.10151054%
# 第 8411 次时:
#  Model's predicted likelihood that the image is a toaster: 0.10259943%
# 第 8421 次时:
#  Model's predicted likelihood that the image is a toaster: 0.10370953%
# 第 8431 次时:
#  Model's predicted likelihood that the image is a toaster: 0.10484569%
# 第 8441 次时:
#  Model's predicted likelihood that the image is a toaster: 0.10601507%
# 第 8451 次时:
#  Model's predicted likelihood that the image is a toaster: 0.10719039%
# 第 8461 次时:
#  Model's predicted likelihood that the image is a toaster: 0.10839986%
# 第 8471 次时:
#  Model's predicted likelihood that the image is a toaster: 0.10963276%
# 第 8481 次时:
#  Model's predicted likelihood that the image is a toaster: 0.11089485%
# 第 8491 次时:
#  Model's predicted likelihood that the image is a toaster: 0.11216929%
# 第 8501 次时:
#  Model's predicted likelihood that the image is a toaster: 0.11344783%
# 第 8511 次时:
#  Model's predicted likelihood that the image is a toaster: 0.11474208%
# 第 8521 次时:
#  Model's predicted likelihood that the image is a toaster: 0.1160766%
# 第 8531 次时:
#  Model's predicted likelihood that the image is a toaster: 0.11741319%
# 第 8541 次时:
#  Model's predicted likelihood that the image is a toaster: 0.11877235%
# 第 8551 次时:
#  Model's predicted likelihood that the image is a toaster: 0.12012904%
# 第 8561 次时:
#  Model's predicted likelihood that the image is a toaster: 0.12149726%
# 第 8571 次时:
#  Model's predicted likelihood that the image is a toaster: 0.12290515%
# 第 8581 次时:
#  Model's predicted likelihood that the image is a toaster: 0.1243692%
# 第 8591 次时:
#  Model's predicted likelihood that the image is a toaster: 0.12586389%
# 第 8601 次时:
#  Model's predicted likelihood that the image is a toaster: 0.12743669%
# 第 8611 次时:
#  Model's predicted likelihood that the image is a toaster: 0.12907361%
# 第 8621 次时:
#  Model's predicted likelihood that the image is a toaster: 0.13075715%
# 第 8631 次时:
#  Model's predicted likelihood that the image is a toaster: 0.13245973%
# 第 8641 次时:
#  Model's predicted likelihood that the image is a toaster: 0.13417897%
# 第 8651 次时:
#  Model's predicted likelihood that the image is a toaster: 0.13594049%
# 第 8661 次时:
#  Model's predicted likelihood that the image is a toaster: 0.13773077%
# 第 8671 次时:
#  Model's predicted likelihood that the image is a toaster: 0.13956663%
# 第 8681 次时:
#  Model's predicted likelihood that the image is a toaster: 0.14142123%
# 第 8691 次时:
#  Model's predicted likelihood that the image is a toaster: 0.14330288%
# 第 8701 次时:
#  Model's predicted likelihood that the image is a toaster: 0.14523752%
# 第 8711 次时:
#  Model's predicted likelihood that the image is a toaster: 0.14719822%
# 第 8721 次时:
#  Model's predicted likelihood that the image is a toaster: 0.14924551%
# 第 8731 次时:
#  Model's predicted likelihood that the image is a toaster: 0.15133682%
# 第 8741 次时:
#  Model's predicted likelihood that the image is a toaster: 0.15350886%
# 第 8751 次时:
#  Model's predicted likelihood that the image is a toaster: 0.15574787%
# 第 8761 次时:
#  Model's predicted likelihood that the image is a toaster: 0.15807702%
# 第 8771 次时:
#  Model's predicted likelihood that the image is a toaster: 0.16048881%
# 第 8781 次时:
#  Model's predicted likelihood that the image is a toaster: 0.16294549%
# 第 8791 次时:
#  Model's predicted likelihood that the image is a toaster: 0.16544203%
# 第 8801 次时:
#  Model's predicted likelihood that the image is a toaster: 0.16806528%
# 第 8811 次时:
#  Model's predicted likelihood that the image is a toaster: 0.17076014%
# 第 8821 次时:
#  Model's predicted likelihood that the image is a toaster: 0.17352785%
# 第 8831 次时:
#  Model's predicted likelihood that the image is a toaster: 0.17634175%
# 第 8841 次时:
#  Model's predicted likelihood that the image is a toaster: 0.17927217%
# 第 8851 次时:
#  Model's predicted likelihood that the image is a toaster: 0.18224153%
# 第 8861 次时:
#  Model's predicted likelihood that the image is a toaster: 0.18527647%
# 第 8871 次时:
#  Model's predicted likelihood that the image is a toaster: 0.1883668%
# 第 8881 次时:
#  Model's predicted likelihood that the image is a toaster: 0.19156605%
# 第 8891 次时:
#  Model's predicted likelihood that the image is a toaster: 0.19483733%
# 第 8901 次时:
#  Model's predicted likelihood that the image is a toaster: 0.19811643%
# 第 8911 次时:
#  Model's predicted likelihood that the image is a toaster: 0.20146247%
# 第 8921 次时:
#  Model's predicted likelihood that the image is a toaster: 0.20495667%
# 第 8931 次时:
#  Model's predicted likelihood that the image is a toaster: 0.20852648%
# 第 8941 次时:
#  Model's predicted likelihood that the image is a toaster: 0.21221966%
# 第 8951 次时:
#  Model's predicted likelihood that the image is a toaster: 0.21604332%
# 第 8961 次时:
#  Model's predicted likelihood that the image is a toaster: 0.21994046%
# 第 8971 次时:
#  Model's predicted likelihood that the image is a toaster: 0.22401039%
# 第 8981 次时:
#  Model's predicted likelihood that the image is a toaster: 0.22831124%
# 第 8991 次时:
#  Model's predicted likelihood that the image is a toaster: 0.23289109%
# 第 9001 次时:
#  Model's predicted likelihood that the image is a toaster: 0.23753482%
# 第 9011 次时:
#  Model's predicted likelihood that the image is a toaster: 0.24228788%
# 第 9021 次时:
#  Model's predicted likelihood that the image is a toaster: 0.24722675%
# 第 9031 次时:
#  Model's predicted likelihood that the image is a toaster: 0.25230509%
# 第 9041 次时:
#  Model's predicted likelihood that the image is a toaster: 0.257599%
# 第 9051 次时:
#  Model's predicted likelihood that the image is a toaster: 0.2630095%
# 第 9061 次时:
#  Model's predicted likelihood that the image is a toaster: 0.26862381%
# 第 9071 次时:
#  Model's predicted likelihood that the image is a toaster: 0.27446887%
# 第 9081 次时:
#  Model's predicted likelihood that the image is a toaster: 0.28057033%
# 第 9091 次时:
#  Model's predicted likelihood that the image is a toaster: 0.28689981%
# 第 9101 次时:
#  Model's predicted likelihood that the image is a toaster: 0.29358426%
# 第 9111 次时:
#  Model's predicted likelihood that the image is a toaster: 0.30054112%
# 第 9121 次时:
#  Model's predicted likelihood that the image is a toaster: 0.30785403%
# 第 9131 次时:
#  Model's predicted likelihood that the image is a toaster: 0.31553144%
# 第 9141 次时:
#  Model's predicted likelihood that the image is a toaster: 0.32376654%
# 第 9151 次时:
#  Model's predicted likelihood that the image is a toaster: 0.33266053%
# 第 9161 次时:
#  Model's predicted likelihood that the image is a toaster: 0.34242317%
# 第 9171 次时:
#  Model's predicted likelihood that the image is a toaster: 0.35308572%
# 第 9181 次时:
#  Model's predicted likelihood that the image is a toaster: 0.36432703%
# 第 9191 次时:
#  Model's predicted likelihood that the image is a toaster: 0.37651183%
# 第 9201 次时:
#  Model's predicted likelihood that the image is a toaster: 0.39048227%
# 第 9211 次时:
#  Model's predicted likelihood that the image is a toaster: 0.40595224%
# 第 9221 次时:
#  Model's predicted likelihood that the image is a toaster: 0.4225865%
# 第 9231 次时:
#  Model's predicted likelihood that the image is a toaster: 0.43940982%
# 第 9241 次时:
#  Model's predicted likelihood that the image is a toaster: 0.45712092%
# 第 9251 次时:
#  Model's predicted likelihood that the image is a toaster: 0.47630728%
# 第 9261 次时:
#  Model's predicted likelihood that the image is a toaster: 0.49720868%
# 第 9271 次时:
#  Model's predicted likelihood that the image is a toaster: 0.52001048%
# 第 9281 次时:
#  Model's predicted likelihood that the image is a toaster: 0.54487716%
# 第 9291 次时:
#  Model's predicted likelihood that the image is a toaster: 0.57199178%
# 第 9301 次时:
#  Model's predicted likelihood that the image is a toaster: 0.60144709%
# 第 9311 次时:
#  Model's predicted likelihood that the image is a toaster: 0.63345535%
# 第 9321 次时:
#  Model's predicted likelihood that the image is a toaster: 0.6716724%
# 第 9331 次时:
#  Model's predicted likelihood that the image is a toaster: 0.71601998%
# 第 9341 次时:
#  Model's predicted likelihood that the image is a toaster: 0.76731369%
# 第 9351 次时:
#  Model's predicted likelihood that the image is a toaster: 0.82740737%
# 第 9361 次时:
#  Model's predicted likelihood that the image is a toaster: 0.89777634%
# 第 9371 次时:
#  Model's predicted likelihood that the image is a toaster: 0.98232524%
# 第 9381 次时:
#  Model's predicted likelihood that the image is a toaster: 1.1002506%
# 第 9391 次时:
#  Model's predicted likelihood that the image is a toaster: 1.2727878%
# 第 9401 次时:
#  Model's predicted likelihood that the image is a toaster: 1.5633717%
# 第 9411 次时:
#  Model's predicted likelihood that the image is a toaster: 2.1439159%
# 第 9421 次时:
#  Model's predicted likelihood that the image is a toaster: 3.653023%
# 第 9431 次时:
#  Model's predicted likelihood that the image is a toaster: 11.661687%
# 第 9438 次时,成功
#  Model's predicted likelihood that the image is a toaster: 92.885023%

# %%
# De-scale the image's pixels from [-1, 1] back to the [0, 255] range
img = hacked_image[0]
img /= 2.
img += 0.5
img *= 255.

# %%
# Save the hacked image!
im = Image.fromarray(img.astype(np.uint8))
im.save("hacked-image.png")
